# %% [markdown]
# - introduction
# - titres des sections
# - interprétation des visuels
# - justification des résultats
# - conclusion
#
#
# procédé de développement de l'outil<br>
# du nettoyage à la modélisation des données<br>
# en
# passant par l’analyse exploratoire
